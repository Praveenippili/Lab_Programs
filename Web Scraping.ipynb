# %%
import urllib.request
page=requests.get("https://www.amazon.in/ref=nav_logo/")
print(page)
print(page.url)
# Out:
# <Response [503]>
# https://www.amazon.in/ref=nav_logo/

# %%
from bs4 import BeautifulSoup
page=requests.get("https://www.amazon.in/ref=nav_logo/")
Soup=BeautifulSoup(page.content,'html.parser')
page_title=Soup.title.text
print(page_title)
# Out:
# Online Shopping site in India: Shop Online for Mobiles, Books, Watches, Shoes and More - Amazon.in

# %%
page_body=Soup.body
print(page_body)
# Out:
# <body class="a-aui_72554-c a-aui_accordion_a11y_role_354025-c a-aui_killswitch_csa_logger_372963-c a-aui_launch_2021_ally_fixes_392482-c a-aui_pci_risk_banner_210084-c a-aui_preload_261698-c a-aui_rel_noreferrer_noopener_309527-c a-aui_template_weblab_cache_333406-c a-aui_tnr_v2_180836-c"><div id="a-page"><script data-a-state='{"key":"a-wlab-states"}' type="a-state">{"AUI_TNR_V2_180836":"C","AUI_ACCORDION_A11Y_ROLE_354025":"C","AUI_PRELOAD_261698":"C","AUI_LAUNCH_2021_ALLY_FIXES_392482":"C","AUI_TEMPLATE_WEBLAB_CACHE_333406":"C","AUI_72554":"C","AUI_KILLSWITCH_CSA_LOGGER_372963":"C","AUI_REL_NOREFERRER_NOOPENER_309527":"C","AUI_PCI_RISK_BANNER_210084":"C"}</script><script>typeof uex === 'function' && uex('ld', 'portal-bb', {wb: 1})</script><!-- sp:end-feature:start-body -->
# <!-- sp:feature:nav-inline-js -->
# <!-- NAVYAAN JS -->
# ...

# %%
page_head=Soup.head
print(page_head)
# Out:
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
import requests
page=requests.get("http://examcell.rguktsklm.ac.in/")
print(page)
print(page.url)
# Out:
# <Response [200]>
# http://examcell.rguktsklm.ac.in/

# %%
import requests
page=requests.get("http://examcell.rguktsklm.ac.in/")
print(page.content)
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n\t\t<title>Examinations &amp; Results :: RGUKT-Srikakulam</title>\n\t\t<link rel="icon" href="#"/>\n\n\t\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t\t<!--==========================================================-->\n\t\t<link rel="stylesheet" href="fonts/css/fontawesome-all.min.css">\n\t\t<!--==========================================================-->\n\t\t<link rel="stylesheet" type="text/css" href="css/main.css">\n\t\t<!--================================================Weekend Test Results:-==========-->\n</head>\n<body>\n\t<!--========== Navigation Bar Code Starts =========-->\n\t\t<div class="topnav" id="myTopnav">\n\t\t  <div class="logo">\n\t\t    <i class="fas fa-university"> </i> &nbsp;Examination Cell\n\t\t  </div>\n\t\t  <a href="#"><i class="fas fa-phone-square" style="padding-right:5px;"></i>Contact</a>\n\t\t  \n\n\t\t  <a href="http://www.rguktsklm.ac.in"><i class="fas fa-home" style="padding-right:5px;"
# ...

# %%
print(page.content)
# Out:
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41C-I1lXVwL.css,31ufSReDtSL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11Qjwq-j69L.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21P6CS3L9LL.css,01oDR3IULNL.css,41CYNGpGlrL.css,01XPHJk60-L.css,01smHc51S9L.css,21aPhFy+riL
# ...

# %%
print(page.url)
# Out:
# https://www.amazon.in/

# %%
import reques
https://www.amazon.in/
url="https://www.amazon.in/"

# %%
https://www.amazon.in/

# %%
from bs4 import BeautifulSoup
p=Soup.find('p')
print(p)
# Out:
# None

# %%
from bs4 import BeautifulSoup
url="https://www.amazon.in/"
page=urllib.request.urlopen(url)
print(page)
pageread=page.read()
pageread
# Out:
# ...
# b'<!doctype html><html lang="en-in" class="a-no-js" data-19ax5a9jf="dingo"><!-- sp:feature:head-start -->\n<head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>\n<!-- sp:end-feature:head-start -->\n\n<!-- sp:feature:cs-optimization -->\n<meta http-equiv=\'x-dns-prefetch-control\' content=\'on\'>\n<link rel="dns-prefetch" href="https://images-eu.ssl-images-amazon.com">\n<link rel="dns-prefetch" href="https://m.media-amazon.com">\n<link rel="dns-prefetch" href="https://completion.amazon.com">\n<!-- sp:end-feature:cs-optimization -->\n\n<!-- sp:feature:aui-assets -->\n<link rel="stylesheet" href="https://images-eu.ssl-images-amazon.com/images/I/11EIQ5IGqaL._RC|01ZTHTZObnL.css,41C-I1lXVwL.css,31ufSReDtSL.css,013z33uKh2L.css,017DsKjNQJL.css,0131vqwP5UL.css,41EWOOlBJ9L.css,11TIuySqr6L.css,01ElnPiDxWL.css,11Qjwq-j69L.css,01Dm5eKVxwL.css,01IdKcBuAdL.css,01y-XAlI+2L.css,21P6CS3L9LL.css,01oDR3IULNL.css,41CYNGpGlrL.css,01XPHJk60-L.css,01smHc51S9L.css,21aPhFy+riL
# ...

# %%
from bs4 import BeautifulSoup
heading_tags=["h1","h2","h3"]
for tags in Soup.find_all(heading_tags):
    print(tags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5812/699226667.py in <module>
#       1 from bs4 import BeautifulSoup
#       2 heading_tags=["h1","h2","h3"]
# ----> 3 for tags in Soup.find_all(heading_tags):
#       4     print(tags)
#
# NameError: name 'Soup' is not defined

# %%
from bs4 import BeautifulSoup
for data in Soup.find_all("p"):
    print(data.get_text())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5812/1387438710.py in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 for data in Soup.find_all("p"):
#       3     print(data.get_text())
#
# NameError: name 'Soup' is not defined

# %%
for x in Soup.find_all("a"):
    print(x.get('href'))
# Out:
# None
# None
# /ref=nav_logo
# None
# /customer-preferences/edit?ie=UTF8&preferencesReturnUrl=%2F&ref_=topnav_lang
# https://www.amazon.in/ap/signin?openid.pape.max_auth_age=0&openid.return_to=https%3A%2F%2Fwww.amazon.in%2F%3F_encoding%3DUTF8%26ref_%3Dnav_ya_signin&openid.identity=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.assoc_handle=inflex&openid.mode=checkid_setup&openid.claimed_id=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0%2Fidentifier_select&openid.ns=http%3A%2F%2Fspecs.openid.net%2Fauth%2F2.0&
# /gp/css/order-history?ref_=nav_orders_first
# https://www.amazon.in/gp/cart/view.html?ref_=nav_cart
# /gp/site-directory?ref_=nav_em_js_disabled
# /gp/bestsellers/?ref_=nav_cs_bestsellers
# /mobile-phones/b/?ie=UTF8&node=1389401031&ref_=nav_cs_mobiles
# /gp/help/customer/display.html?nodeId=200507590&ref_=nav_cs_help
# /deals?ref_=nav_cs_gb
# /Books/b/?ie=UTF8&node=976389031&ref_=nav_cs_books
# /electronics/b/?ie=UTF8&node=976419031&ref_=nav_cs_electronics
# ...

# %%
for data in Soup.find_all("p"):
    print(data.get_text())

# %%
print(page_title)
# Out:
# Online Shopping site in India: Shop Online for Mobiles, Books, Watches, Shoes and More - Amazon.in

# %%
for x in Soup.find_all("src"):
    print(x.get("src"))

# %%
page_head=Soup.head
print(page_head)
# Out:
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link href="https://completion.amazon.com" rel="dns-prefetch"/>
# <!-- sp:end-feature:cs-optimization -->
# <!-- sp:feature:aui-assets -->
# ...

# %%
title=Soup.title
print(title)
print(title.string)
print(type(title))
print(type(title.string))
# Out:
# <title>Online Shopping site in India: Shop Online for Mobiles, Books, Watches, Shoes and More - Amazon.in</title>
# Online Shopping site in India: Shop Online for Mobiles, Books, Watches, Shoes and More - Amazon.in
# <class 'bs4.element.Tag'>
# <class 'bs4.element.NavigableString'>

# %%
from bs4 import BeautifulSoup
page_ime=Soup.img
print(Soup.find_all("img"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2264/3646590874.py in <module>
#       1 from bs4 import BeautifulSoup
# ----> 2 page_ime=Soup.img
#       3 print(Soup.find_all("img"))
#
# NameError: name 'Soup' is not defined
